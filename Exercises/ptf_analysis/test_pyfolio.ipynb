# %%
import pyfolio as pf
import pandas as pd
import numpy as np

# Print version of pandas, numpy and pyfolio
print(f'{pd.__version__=}')
print(f'{np.__version__=}')
print(f'{pf.__version__=}')
# Out:
# c:\Users\phil7\Code\coding_finance\.venv\lib\site-packages\pyfolio\pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# pd.__version__='2.2.2'
# np.__version__='2.0.2'
# pf.__version__='0.9.8'

# %%
# Generate some random returns data
returns = pd.Series(
    np.random.normal(loc=0.001, scale=0.02, size=1000),
    index=pd.date_range(start='2020-01-01', periods=1000, freq='D')
)
returns
# Out:
# 2020-01-01   -0.016220
# 2020-01-02   -0.005362
# 2020-01-03    0.024267
# 2020-01-04    0.004458
# 2020-01-05    0.019322
#                 ...
# 2022-09-22    0.013964
# 2022-09-23   -0.033699
# 2022-09-24    0.004343
# 2022-09-25    0.014634
# 2022-09-26   -0.040192
# Freq: D, Length: 1000, dtype: float64

# %%
# Create a tear sheet
pf.create_simple_tear_sheet(returns)
# Out:
# c:\Users\phil7\Code\coding_finance\.venv\lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '57.875%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-09-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>47</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>57.875%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>512.296%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>30.996%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.63</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.31</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-44.189%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.29</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.55</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>-0.14</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.19</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.705%</td>
#     </tr>
#   </tbody>
# </table>
