# %%
import pyfolio as pf
import pandas as pd
import numpy as np

# Print version of pandas, numpy and pyfolio
print(f'{pd.__version__=}')
print(f'{np.__version__=}')
print(f'{pf.__version__=}')
# Out:
# pd.__version__='2.2.2'
# np.__version__='1.26.4'
# pf.__version__='0.9.7'

# %%
# Generate some random returns data
returns = pd.Series(
    np.random.normal(loc=0.001, scale=0.02, size=1000),
    index=pd.date_range(start='2020-01-01', periods=1000, freq='D')
)
returns
# Out:
# 2020-01-01    0.024234
# 2020-01-02    0.008172
# 2020-01-03    0.009018
# 2020-01-04    0.001465
# 2020-01-05    0.014457
#                 ...
# 2022-09-22    0.002179
# 2022-09-23   -0.002845
# 2022-09-24    0.003024
# 2022-09-25   -0.022732
# 2022-09-26    0.018271
# Freq: D, Length: 1000, dtype: float64

# %%
# Create a tear sheet
pf.create_simple_tear_sheet(returns)
# Out:
# c:\Users\phil7\OneDrive\Code\coding_finance\.venv\lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.698%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-09-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>47</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>14.698%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>72.318%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>31.827%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.59</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.40</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.67</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-36.581%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.10</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.07</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>0.25</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.935%</td>
#     </tr>
#   </tbody>
# </table>
