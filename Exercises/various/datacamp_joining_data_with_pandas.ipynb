# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import pickle
from  common import load_data

# %%
# Loading Data
sub_data_folder = 'dc/joining_data'
file_name = 'ward.p'

wards = load_data(file_name, 'pkl', sub_data_folder)
print(wards.info())
print(wards.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ward      50 non-null     object
#  1   alderman  50 non-null     object
#  2   address   50 non-null     object
#  3   zip       50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB
# None
#   ward            alderman                          address    zip
# 0    1  Proco "Joe" Moreno        2058 NORTH WESTERN AVENUE  60647
# 1    2       Brian Hopkins       1400 NORTH  ASHLAND AVENUE  60622
# 2    3          Pat Dowell          5046 SOUTH STATE STREET  60609
# 3    4    William D. Burns  435 EAST 35TH STREET, 1ST FLOOR  60616
# 4    5  Leslie A. Hairston            2325 EAST 71ST STREET  60649

# %%
file_name = 'census.p'
census = load_data(file_name, 'pkl', sub_data_folder)
print(census.info())
print(census.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ward      50 non-null     object
#  1   pop_2000  50 non-null     int64
#  2   pop_2010  50 non-null     int64
#  3   change    50 non-null     object
#  4   address   50 non-null     object
#  5   zip       50 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.5+ KB
# None
#   ward  pop_2000  pop_2010 change                                  address  \
# 0    1     52951     56149     6%              2765 WEST SAINT MARY STREET
# 1    2     54361     55805     3%                 WM WASTE MANAGEMENT 1500
# 2    3     40385     53039    31%                      17 EAST 38TH STREET
# 3    4     51953     54589     5%  31ST ST HARBOR BUILDING LAKEFRONT TRAIL
# 4    5     55302     51455    -7%  JACKSON PARK LAGOON SOUTH CORNELL DRIVE
#
#      zip
# 0  60647
# 1  60622
# 2  60653
# ...

# %%
wards_census = wards.merge(census, on='ward', suffixes=('_ward','_cen'))
print(wards_census.head())
# Out:
#   ward            alderman                     address_ward zip_ward  \
# 0    1  Proco "Joe" Moreno        2058 NORTH WESTERN AVENUE    60647
# 1    2       Brian Hopkins       1400 NORTH  ASHLAND AVENUE    60622
# 2    3          Pat Dowell          5046 SOUTH STATE STREET    60609
# 3    4    William D. Burns  435 EAST 35TH STREET, 1ST FLOOR    60616
# 4    5  Leslie A. Hairston            2325 EAST 71ST STREET    60649
#
#    pop_2000  pop_2010 change                              address_cen zip_cen
# 0     52951     56149     6%              2765 WEST SAINT MARY STREET   60647
# 1     54361     55805     3%                 WM WASTE MANAGEMENT 1500   60622
# 2     40385     53039    31%                      17 EAST 38TH STREET   60653
# 3     51953     54589     5%  31ST ST HARBOR BUILDING LAKEFRONT TRAIL   60653
# 4     55302     51455    -7%  JACKSON PARK LAGOON SOUTH CORNELL DRIVE   60637

# %%
file_name = 'licenses.p'
licenses = load_data(file_name, 'pkl', sub_data_folder)
print(licenses.info())
print(licenses.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   account   10000 non-null  object
#  1   ward      10000 non-null  object
#  2   aid       4657 non-null   object
#  3   business  10000 non-null  object
#  4   address   10000 non-null  object
#  5   zip       9996 non-null   object
# dtypes: object(6)
# memory usage: 468.9+ KB
# None
#   account ward  aid                   business               address    zip
# 0  307071    3  743       REGGIE'S BAR & GRILL       2105 S STATE ST  60616
# 1      10   10  829                 HONEYBEERS   13200 S HOUSTON AVE  60633
# 2   10002   14  775                CELINA DELI     5089 S ARCHER AVE  60632
# 3   10005   12  NaN  KRAFT FOODS NORTH AMERICA        2005 W 43RD ST  60609
# 4   10044   44  638  NEYBOUR'S TAVERN & GRILLE  3651 N SOUTHPORT AVE  60613

# %%
ward_licenses = wards.merge(licenses, on='ward', suffixes=('_ward', '_lic'))
ward_licenses
# Out:
#      ward              alderman                     address_ward zip_ward  \
# 0       1    Proco "Joe" Moreno        2058 NORTH WESTERN AVENUE    60647
# 1       1    Proco "Joe" Moreno        2058 NORTH WESTERN AVENUE    60647
# 2       1    Proco "Joe" Moreno        2058 NORTH WESTERN AVENUE    60647
# 3       1    Proco "Joe" Moreno        2058 NORTH WESTERN AVENUE    60647
# 4       1    Proco "Joe" Moreno        2058 NORTH WESTERN AVENUE    60647
# ...   ...                   ...                              ...      ...
# 9995   50  Debra L. Silverstein  2949 WEST DEVON AVENUE, SUITE A    60659
# 9996   50  Debra L. Silverstein  2949 WEST DEVON AVENUE, SUITE A    60659
# 9997   50  Debra L. Silverstein  2949 WEST DEVON AVENUE, SUITE A    60659
# 9998   50  Debra L. Silverstein  2949 WEST DEVON AVENUE, SUITE A    60659
# 9999   50  Debra L. Silverstein  2949 WEST DEVON AVENUE, SUITE A    60659
#
#      account  aid                        business               address_lic  \
# ...

# %%
file_name = 'movies.p'
movies = load_data(file_name, 'pkl', sub_data_folder)
print(movies.info())
print(movies.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4803 non-null   int64
#  1   title         4803 non-null   object
#  2   popularity    4803 non-null   float64
#  3   release_date  4802 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 150.2+ KB
# None
#       id                 title  popularity release_date
# 0    257          Oliver Twist   20.415572   2005-09-23
# 1  14290  Better Luck Tomorrow    3.877036   2002-01-12
# 2  38365             Grown Ups   38.864027   2010-06-24
# 3   9672              Infamous    3.680896   2006-11-16
# 4  12819       Alpha and Omega   12.300789   2010-09-17

# %%
file_name = 'taglines.p'
taglines = load_data(file_name, 'pkl', sub_data_folder)
print(taglines.info())
print(taglines.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3955 entries, 0 to 4801
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3955 non-null   int64
#  1   tagline  3955 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 92.7+ KB
# None
#        id                                         tagline
# 0   19995                     Enter the World of Pandora.
# 1     285  At the end of the world, the adventure begins.
# 2  206647                           A Plan No One Escapes
# 3   49026                                 The Legend Ends
# 4   49529            Lost in our world, found in another.

# %%
movies_taglines = pd.merge(movies,taglines, on='id', how='left')
movies_taglines
# Out:
#          id                 title  popularity release_date  \
# 0       257          Oliver Twist   20.415572   2005-09-23
# 1     14290  Better Luck Tomorrow    3.877036   2002-01-12
# 2     38365             Grown Ups   38.864027   2010-06-24
# 3      9672              Infamous    3.680896   2006-11-16
# 4     12819       Alpha and Omega   12.300789   2010-09-17
# ...     ...                   ...         ...          ...
# 4798   3089             Red River    5.344815   1948-08-26
# 4799  11934   The Hudsucker Proxy   14.188982   1994-03-11
# 4800  13807                Exiled    8.486390   2006-09-06
# 4801  73873          Albert Nobbs    7.802245   2011-12-21
# 4802  11622   Blast from the Past    8.737058   1999-02-12
#
#                                                 tagline
# 0                                                   NaN
# 1                  Never underestimate an overachiever.
# 2       Boys will be boys. . . some longer than others.
# ...

# %%
movies_taglines_right = pd.merge(movies,taglines, on='id', how='right')
movies_taglines_right
# Out:
#           id                                     title  popularity  \
# 0      19995                                    Avatar  150.437577
# 1        285  Pirates of the Caribbean: At World's End  139.082615
# 2     206647                                   Spectre  107.376788
# 3      49026                     The Dark Knight Rises  112.312950
# 4      49529                               John Carter   43.926995
# ...      ...                                       ...         ...
# 3950  124606                                      Bang    0.918116
# 3951   14337                                    Primer   23.307949
# 3952    9367                               El Mariachi   14.269792
# 3953   72766                                 Newlyweds    0.642552
# 3954  126186                          Shanghai Calling    0.857008
#
#      release_date                                            tagline
# 0      2009-12-10                        Enter the World of Pandora.
# ...

# %%
file_name = 'movie_to_genres.p'
movie_genres = load_data(file_name, 'pkl', sub_data_folder)
print(movie_genres.info())
print(movie_genres.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12160 entries, 0 to 12159
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  12160 non-null  int64
#  1   genre     12160 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 190.1+ KB
# None
#    movie_id            genre
# 0         5            Crime
# 1         5           Comedy
# 2        11  Science Fiction
# 3        11           Action
# 4        11        Adventure

# %%
tv_genre = movie_to_genres[movie_genres['genre'] == 'TV Movie']
print(tv_genre)
# Out:
#        movie_id     genre
# 4998      10947  TV Movie
# 5994      13187  TV Movie
# 7443      22488  TV Movie
# 10061     78814  TV Movie
# 10790    153397  TV Movie
# 10835    158150  TV Movie
# 11096    205321  TV Movie
# 11282    231617  TV Movie

# %%
movies
# Out:
#          id                 title  popularity release_date
# 0       257          Oliver Twist   20.415572   2005-09-23
# 1     14290  Better Luck Tomorrow    3.877036   2002-01-12
# 2     38365             Grown Ups   38.864027   2010-06-24
# 3      9672              Infamous    3.680896   2006-11-16
# 4     12819       Alpha and Omega   12.300789   2010-09-17
# ...     ...                   ...         ...          ...
# 4798   3089             Red River    5.344815   1948-08-26
# 4799  11934   The Hudsucker Proxy   14.188982   1994-03-11
# 4800  13807                Exiled    8.486390   2006-09-06
# 4801  73873          Albert Nobbs    7.802245   2011-12-21
# 4802  11622   Blast from the Past    8.737058   1999-02-12
#
# [4803 rows x 4 columns]

# %%
movies.merge(tv_genre, left_on='id', right_on='movie_id', how='right')
# Out:
#        id                      title  popularity release_date  movie_id  \
# 0   10947        High School Musical   16.536374   2006-01-20     10947
# 1   13187  A Charlie Brown Christmas    8.701183   1965-12-09     13187
# 2   22488         Love's Abiding Joy    1.128559   2006-10-06     22488
# 3   78814       We Have Your Husband    0.102003   2011-11-12     78814
# 4  153397                   Restless    0.812776   2012-12-07    153397
# 5  158150        How to Fall in Love    1.923514   2012-07-21    158150
# 6  205321                  Sharknado   20.466433   2013-07-11    205321
# 7  231617  Signed, Sealed, Delivered    1.444476   2013-10-13    231617
#
#       genre
# 0  TV Movie
# 1  TV Movie
# 2  TV Movie
# 3  TV Movie
# 4  TV Movie
# 5  TV Movie
# 6  TV Movie
# 7  TV Movie

# %%
import calendar

# %%
calendar.month_abbr[1]
# Out:
# 'Jan'
